# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import skimage.io

from src.utils import load_images

# %% [markdown]
# ## Load preprocessed data

# %%
# Load ground truths.
ims_gt = load_images()
ims_gt.shape
# Out:
# (15, 1000, 1000, 3)

# %%
# Load downsampled.
ims_ds = load_images('data/healthy_ds4')
ims_ds.shape
# Out:
# (15, 1000, 1000, 3)

# %%
# Load in torch (model requires batch x channels x height x width)
device = torch.device("cpu")
gt_data = torch.tensor(ims_gt.transpose((0,3,1,2)), device=device)
ds_data = torch.tensor(ims_ds.transpose((0,3,1,2)), device=device)
gt_data.shape
# Out:
# torch.Size([15, 3, 1000, 1000])

# %% [markdown]
# ## Show data

# %%
fig, axs = plt.subplots(4,3,figsize=(20,25))
for i, ax in enumerate(axs):
    ax[0].imshow(ims_gt[i])
    ax[1].imshow(ims_ds[i])
    ax[2].imshow(ims_ds[i][500:600, 500:600])
plt.show()
